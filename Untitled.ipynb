# %%
import json


json_data = '''{
  "cells": [
    {
      "cell_type": "code",
      "execution_count": 1,
      "id": "dc04835b-3f7a-41cf-b638-56353d442519",
      "metadata": {},
      "outputs": [],
      "source": [
        "import streamlit as st\\n",
        "import joblib\\n",
        "import pandas as pd\\n",
        "import numpy as np"
      ]
    },
    {
      "cell_type": "code",
      "execution_count": 5,
      "id": "eca6b522-44e3-40b5-bc50-78e40694dfb6",
      "metadata": {},
      "outputs": [],
      "source": [
        "model = joblib.load('eniyi_model.joblib') "
      ]
    },
    {
      "cell_type": "code",
      "execution_count": 7,
      "id": "fc9ad06c-065d-4df9-99c5-dfeab2a9b80f",
      "metadata": {},
      "outputs": [],
      "source": [
        "st.title('Cep Telefonu Fiyat Tahmin Uygulaması')"
      ]
    },
    {
      "cell_type": "code",
      "execution_count": 9,
      "id": "b9fb82b0-e142-442e-be74-aae30e4eed9e",
      "metadata": {},
      "outputs": [],
      "source": [
        "st.header('Telefon Özelliklerini Giriniz')"
      ]
    },
    {
      "cell_type": "code",
      "execution_count": 11,
      "id": "dd04906e-d358-46fe-9ee7-b363630ff4ca",
      "metadata": {},
      "outputs": [],
      "source": [
        "ram = st.number_input('RAM Kapasitesi (GB)', min_value=1, max_value=16, step=1)\\n",
        "kamera_cozunurlugu = st.number_input('Kamera Çözünürlüğü (MP)', min_value=8, max_value=108, step=1)\\n",
        "dahili_hafiza = st.number_input('Dahili Hafıza (GB)', min_value=16, max_value=1000, step=16)\\n",
        "on_kamera_cozunurlugu = st.number_input('Ön Kamera Çözünürlüğü (MP)', min_value=5, max_value=64, step=1)\\n",
        "isletim_sistemi = st.selectbox('İşletim Sistemi', ['Android', 'iOS'])\\n"
      ]
    },
    {
      "cell_type": "code",
      "execution_count": 13,
      "id": "3b9241bf-4c4a-4f23-a0ac-4521f916dbc8",
      "metadata": {},
      "outputs": [],
      "source": [
        "isletim_sistemi = 0 if isletim_sistemi == 'Android' else 1"
      ]
    },
    {
      "cell_type": "code",
      "execution_count": 15,
      "id": "eab79e19-1828-4ee3-9453-4bc26f97da3c",
      "metadata": {},
      "outputs": [],
      "source": [
        "user_input = pd.DataFrame({\\n",
        "    'RAM Kapasitesi': [ram],\\n",
        "    'Kamera Çözünürlüğü': [kamera_cozunurlugu],\\n",
        "    'Dahili Hafıza': [dahili_hafiza],\\n",
        "    'Ön Kamera Çözünürlüğü': [on_kamera_cozunurlugu],\\n",
        "    'İşletim Sistemi': [isletim_sistemi]\\n",
        "})"
      ]
    },
    {
      "cell_type": "code",
      "execution_count": 17,
      "id": "07dbfea6-2bd3-42f1-8773-4e6ddb4bd672",
      "metadata": {},
      "outputs": [],
      "source": [
        "if st.button('Fiyatı Tahmin Et'):\\n",
        "    \\n",
        "    tahmin_fiyat = model.predict(user_input)\\n",
        "    \\n",
        "    \\n",
        "    st.subheader(f'Tahmin Edilen Fiyat: {tahmin_fiyat[0]:.2f} TL')"
      ]
    }
  ],
  "metadata": {},
  "nbformat": 4,
  "nbformat_minor": 5
}'''


data = json.loads(json_data)


python_code = ""
for cell in data['cells']:
    if cell['cell_type'] == 'code':
        python_code += ''.join(cell['source']) + '\n\n'

with open("websitesi.py", "w") as file:
    file.write(python_code)

print("Python dosyası oluşturuldu.")
# Out:
# Python dosyası oluşturuldu.
